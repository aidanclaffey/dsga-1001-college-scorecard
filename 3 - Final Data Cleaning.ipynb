# %%
import pickle
import numpy as np
import pandas as pd

# %%
X = data = pickle.load(open('merged_earnings_df.pickle', 'rb'))
X
# Out:
#                                          INSTNM STABBR ACCREDAGENCY  HCM2  \
# 0                      Alabama A & M University     AL          NaN   NaN
# 1           University of Alabama at Birmingham     AL          NaN   NaN
# 2           University of Alabama in Huntsville     AL          NaN   NaN
# 3                      Alabama State University     AL          NaN   NaN
# 4                     The University of Alabama     AL          NaN   NaN
# ...                                         ...    ...          ...   ...
# 11340  Pierpont Community and Technical College     WV          NaN   NaN
# 11341           University of California-Merced     CA          NaN   NaN
# 11342          Pima Medical Institute-Las Vegas     NV          NaN   NaN
# 11343      Johnson & Wales University-Charlotte     NC          NaN   NaN
# 11344                West Hills College-Lemoore     CA          NaN   NaN
#
#                   MAIN  NUMBRANCH      PREDDEG     HIGHDEG  \
# 0          Main campus        1.0     bachelor    Graduate
# 1          Main campus        1.0     bachelor    Graduate
# 2          Main campus        1.0     bachelor    Graduate
# 3          Main campus        1.0     bachelor    Graduate
# 4          Main campus        1.0     bachelor    Graduate
# ...                ...        ...          ...         ...
# 11340      Main campus        1.0    associate   Associate
# 11341      Main campus        1.0     bachelor    Graduate
# 11342  Not main campus        9.0  certificate   Associate
# 11343  Not main campus        4.0    associate  Bachelor's
# 11344      Main campus        1.0    associate   Associate
#
#                   CONTROL      REGION  ...  PRGMOFR    YEAR  COSTT4  \
# 0                  Public  Southeast   ...      NaN  2002.0     NaN
# 1                  Public  Southeast   ...      NaN  2002.0     NaN
# 2                  Public  Southeast   ...      NaN  2002.0     NaN
# 3                  Public  Southeast   ...      NaN  2002.0     NaN
# 4                  Public  Southeast   ...      NaN  2002.0     NaN
# ...                   ...         ...  ...      ...     ...     ...
# 11340              Public  Southeast   ...      NaN  2008.0     NaN
# 11341              Public   Far West   ...      NaN  2008.0     NaN
# 11342  Private for-profit   Far West   ...      9.0  2008.0     NaN
# 11343   Private nonprofit  Southeast   ...      NaN  2008.0     NaN
# 11344              Public   Far West   ...      NaN  2008.0     NaN
#
#        COUNT_WNE_P6_year_1  MD_EARN_WNE_P6_year_1  _merged_1  \
# 0                   1291.0           26517.618782       both
# 1                   2882.0           36806.454870       both
# 2                   1082.0           41049.273875       both
# 3                   1520.0           21850.517876       both
# 4                   2917.0           37548.948195       both
# ...                    ...                    ...        ...
# 11340                  0.0               0.000000  left_only
# 11341                  0.0               0.000000  left_only
# 11342                  0.0               0.000000  left_only
# 11343                  0.0               0.000000  left_only
# 11344                  0.0               0.000000  left_only
#
#        COUNT_WNE_P6_year_2  MD_EARN_WNE_P6_year_2  _merged_2   MD_EARN_AVG
# 0                      0.0               0.000000  left_only  26517.618782
# 1                      0.0               0.000000  left_only  36806.454870
# 2                      0.0               0.000000  left_only  41049.273875
# 3                      0.0               0.000000  left_only  21850.517876
# 4                      0.0               0.000000  left_only  37548.948195
# ...                    ...                    ...        ...           ...
# 11340                  0.0           25917.946720       both  25917.946720
# 11341               1189.0           37801.274070       both  37801.274070
# 11342               8268.0           27352.141400       both  27352.141400
# 11343               7340.0           32679.150212       both  32679.150212
# 11344               1412.0           24586.194517       both  24586.194517
#
# [11339 rows x 106 columns]

# %%
categorical_keys = [
    "STABBR",
    "ACCREDAGENCY",
    "PREDDEG",
    "HIGHDEG",
    "CONTROL",
    "REGION",
    "LOCALE",
    "CCBASIC",
    "CCUGPROF",
    "CCSIZSET",
    "RELAFFIL",
   # "ICLEVEL",
]

# %%
X = pd.get_dummies(
    X,
    dummy_na=True,
    columns=[*[col for col in categorical_keys if col in X.columns], "STABBR"],
    drop_first=True,
)

# %%
X.loc[:, "MD_EARN_AVG"].isna().value_counts()
# Out:
# False    11339
# Name: MD_EARN_AVG, dtype: int64

# %%
y = X.MD_EARN_AVG
X.drop("MD_EARN_AVG", axis=1, inplace=True)

# %%
X.YEAR.value_counts()
# Out:
# 2007.0    1678
# 2006.0    1677
# 2005.0    1667
# 2008.0    1587
# 2003.0    1580
# 2004.0    1576
# 2002.0    1574
# Name: YEAR, dtype: int64

# %%
with open("clean_data.pickle", "wb") as f:
    pickle.dump(
        {
            "X": X,
            'y': y
        },
        f,
    )

# %%
with open('clean_data.pickle','rb') as f:
    d = pickle.load(f)
    X = d['X']
    y = d['y']
    del(d)

# %%
X.isna()
# Out:
#        INSTNM  HCM2   MAIN  NUMBRANCH  HBCU  MENONLY  WOMENONLY  ADM_RATE  \
# 0       False  True  False      False  True     True       True     False
# 1       False  True  False      False  True     True       True     False
# 2       False  True  False      False  True     True       True     False
# 3       False  True  False      False  True     True       True     False
# 4       False  True  False      False  True     True       True     False
# ...       ...   ...    ...        ...   ...      ...        ...       ...
# 11340   False  True  False      False  True     True       True      True
# 11341   False  True  False      False  True     True       True     False
# 11342   False  True  False      False  True     True       True      True
# 11343   False  True  False      False  True     True       True     False
# 11344   False  True  False      False  True     True       True      True
#
#        SATVR25  SATVR75  ...  STABBR_TX  STABBR_UT  STABBR_VA  STABBR_VI  \
# 0         True     True  ...      False      False      False      False
# 1         True     True  ...      False      False      False      False
# 2        False    False  ...      False      False      False      False
# 3        False    False  ...      False      False      False      False
# 4        False    False  ...      False      False      False      False
# ...        ...      ...  ...        ...        ...        ...        ...
# 11340     True     True  ...      False      False      False      False
# 11341    False    False  ...      False      False      False      False
# 11342     True     True  ...      False      False      False      False
# 11343     True     True  ...      False      False      False      False
# 11344     True     True  ...      False      False      False      False
#
#        STABBR_VT  STABBR_WA  STABBR_WI  STABBR_WV  STABBR_WY  STABBR_nan
# 0          False      False      False      False      False       False
# 1          False      False      False      False      False       False
# 2          False      False      False      False      False       False
# 3          False      False      False      False      False       False
# 4          False      False      False      False      False       False
# ...          ...        ...        ...        ...        ...         ...
# 11340      False      False      False      False      False       False
# 11341      False      False      False      False      False       False
# 11342      False      False      False      False      False       False
# 11343      False      False      False      False      False       False
# 11344      False      False      False      False      False       False
#
# [11339 rows x 302 columns]

# %%
non_empty_cols = (X.isna().sum() / X.shape[0]) != 1
non_empty_col_names = [col for col, v in non_empty_cols.to_dict().items() if v]
X = X[non_empty_col_names]
col_pct = (X.isna().sum() / X.shape[0])
col_pct_nonzero = pd.Series({c: p for c, p in col_pct.to_dict().items() if p > 0})
col_pct_nonzero.sort_values(ascending=False)
# Out:
# TUITIONFEE_PROG     0.983332
# PRGMOFR             0.983244
# ACTWR75             0.983244
# ACTWRMID            0.983244
# ACTWR25             0.983244
# SATWR25             0.899462
# SATWR75             0.899462
# SATWRMID            0.899462
# PCTPELL             0.860041
# COMPL_RPY_1YR_RT    0.757298
# ACTMTMID            0.617515
# ACTMT75             0.617515
# ACTMT25             0.617427
# ACTEN75             0.616633
# ACTENMID            0.616633
# ACTEN25             0.616545
# UG25ABV             0.565747
# ACTCMMID            0.532498
# ACTCM75             0.532498
# ACTCM25             0.532410
# SATVRMID            0.504101
# SATVR75             0.504013
# SATVR25             0.504013
# SATMTMID            0.502778
# SATMT75             0.502778
# SATMT25             0.502690
# ADM_RATE            0.368904
# C150_4              0.354529
# GRAD_DEBT_MDN       0.136520
# TUITIONFEE_OUT      0.022224
# TUITIONFEE_IN       0.022224
# AVGFACSAL           0.005821
# INEXPFTE            0.002381
# PFTFAC              0.001499
# dtype: float64

# %%
naive_impute_avg = [
    "PFTFAC",
    "INEXPFTE",
    "AVGFACSAL",
    "GRAD_DEBT_MDN",
    "C150_4",
    "ADM_RATE",
]
for col in naive_impute_avg:
    X.loc[:,f"{col}_ISNA"] = X[col].isna().astype(int)
    X.loc[:,col] = X[col].fillna(X[col].mean())

# %%
X.loc[:,"TUITION_ISNA"] = X["TUITIONFEE_OUT"].isna().astype(int)

# %%
X.loc[:, "TUITIONFEE_IN"] = X["TUITIONFEE_IN"].fillna(value=X["TUITIONFEE_PROG"])
X.loc[:, "TUITIONFEE_OUT"] = X["TUITIONFEE_OUT"].fillna(value=X["TUITIONFEE_PROG"])
X.loc[:, "TUITION_OUT_ISNT_IN"] = (X["TUITIONFEE_IN"] != X["TUITIONFEE_OUT"]).astype(
    int
)
X = X.dropna(subset=["TUITIONFEE_OUT"], how="any", axis="rows")
X = X.drop("TUITIONFEE_PROG", axis=1)
X = X.drop("PRGMOFR", axis=1)

# %%
X.shape
# Out:
# (11276, 298)

# %%
non_empty_cols = (X.isna().sum() / X.shape[0]) != 1
non_empty_col_names = [col for col, v in non_empty_cols.to_dict().items() if v]
X = X[non_empty_col_names]
col_pct = (X.isna().sum() / X.shape[0])
col_pct_nonzero = pd.Series({c: p for c, p in col_pct.to_dict().items() if p > 0})
col_pct_nonzero.sort_values(ascending=False)
# Out:
# ACTWRMID            0.983239
# ACTWR75             0.983239
# ACTWR25             0.983239
# SATWRMID            0.899166
# SATWR25             0.899166
# SATWR75             0.899166
# PCTPELL             0.859879
# COMPL_RPY_1YR_RT    0.757272
# ACTMTMID            0.617329
# ACTMT75             0.617329
# ACTMT25             0.617240
# ACTENMID            0.616442
# ACTEN75             0.616442
# ACTEN25             0.616353
# UG25ABV             0.565981
# ACTCM75             0.532192
# ACTCMMID            0.532192
# ACTCM25             0.532104
# SATVRMID            0.503991
# SATVR75             0.503902
# SATVR25             0.503902
# SATMTMID            0.502661
# SATMT75             0.502661
# SATMT25             0.502572
# dtype: float64
